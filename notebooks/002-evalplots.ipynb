# %%
import config
from datetime import date
from src.post_analysis import EvalPlot

import warnings
warnings.filterwarnings('ignore')

# %%
eval_config = config.EVAL_CONFIG
eval_config['USER_IDS'] = [1802,1806]  # choose a list of user ids to plot evaluation from

# %%
current_time = date.today().strftime("%Y-%m-%d")
filename = f"evalplot-matrix-{current_time}.pdf"

eval_plot_matrix = EvalPlot(eval_config)
eval_plot_matrix.plots(filename)
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
